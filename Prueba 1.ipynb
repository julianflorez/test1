# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/julianflorez/Desktop/Fact_H1_2022.csv', sep=';', encoding_errors='ignore')

# %%
df.head()
# Out:
#   No FACTURA FECHA DE EMISIN FECHA DE VENCIMIENTO  \
# 0        861      2022-01-03           2022-02-03
# 1        862      2022-01-03           2022-02-03
# 2        863      2022-01-03           2022-02-03
# 3        864      2022-01-03           2022-02-03
# 4        865      2022-01-03           2022-02-03
#
#    PROYECTO / CENTRO DE COSTOS  ASESOR COMERCIAL                  CLIENTE  \
# 0                         3001               NaN  TERRANUM DESARROLLO SAS
# 1                         1066               NaN  TERRANUM DESARROLLO SAS
# 2                         3001               NaN  TERRANUM DESARROLLO SAS
# 3                         3001               NaN  TERRANUM DESARROLLO SAS
# 4                         3001               NaN  TERRANUM DESARROLLO SAS
#
#                                   CONCEPTO  VALOR FACTURA      IVA  \
# 0                   CAMARAS SOTANO TANQUES       17929968  3406694
# 1                     SISTEMA LPR CONNECTA       21540492  4092693
# ...

# %%
df.describe()
# Out:
#        PROYECTO / CENTRO DE COSTOS  ASESOR COMERCIAL  VALOR FACTURA  \
# count                   344.000000               0.0   3.440000e+02
# mean                   2720.796512               NaN   5.937229e+06
# std                    1226.865267               NaN   1.686151e+09
# min                     926.000000               NaN  -2.040193e+10
# 25%                    2043.500000               NaN   3.597250e+05
# 50%                    3001.000000               NaN   1.896398e+06
# 75%                    3026.250000               NaN   5.688500e+06
# max                    9129.000000               NaN   2.040193e+10
#
#                 IVA  AMORTIZACIN ANTICIPO
# count  3.440000e+02                   0.0
# mean   9.364644e+05                   NaN
# std    3.203646e+08                   NaN
# min   -3.876366e+09                   NaN
# 25%    6.310100e+04                   NaN
# 50%    3.378135e+05                   NaN
# 75%    1.027764e+06                   NaN
# ...
